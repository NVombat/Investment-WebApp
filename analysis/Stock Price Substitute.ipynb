# %%
import yfinance as yf
import json

# %%
symbol = "GOOGL"
ticker = yf.Ticker(symbol)

# %%
ticker
# Out:
# yfinance.Ticker object <GOOGL>

# %%
pip install pynance
# Out:
# ...
#      |████████████████████████████████| 42 kB 14 kB/s  eta 0:00:011
# ...
#      |████████████████████████████████| 62 kB 159 kB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pynance as pn

# %%
data = pn.data.get("googl", "2020", "2021")

# %%
data
# Out:
#                Open     High      Low    Close   Volume
# Date
# 2020-12-31  1737.27  1757.50  1736.09  1752.64  1053479
# 2020-12-30  1765.00  1767.76  1728.00  1736.25  1051308
# 2020-12-29  1787.23  1788.47  1755.11  1757.76   986287
# 2020-12-28  1744.91  1787.00  1741.82  1773.96  1382537
# 2020-12-24  1729.00  1742.41  1724.35  1734.16   465638
# ...             ...      ...      ...      ...      ...
# 2020-01-08  1394.82  1411.85  1392.63  1405.04  1766274
# 2020-01-07  1400.46  1403.50  1391.56  1395.11  1726456
# 2020-01-06  1351.63  1398.32  1351.00  1397.81  2339343
# 2020-01-03  1348.00  1373.75  1347.32  1361.52  1170629
# 2020-01-02  1348.41  1368.68  1346.49  1368.68  1364265
#
# [253 rows x 5 columns]

# %%
data = pn.data.get("googl", start="2021", end=None)
data
# Out:
#                 Open       High        Low    Close   Volume
# Date
# 2021-09-10  2884.250  2894.3700  2814.7550  2817.52  1841967
# 2021-09-09  2876.810  2886.2100  2863.5500  2870.82   765855
# 2021-09-08  2882.000  2888.0000  2860.0000  2873.82   917511
# 2021-09-07  2876.690  2891.3000  2872.3800  2885.61  1006595
# 2021-09-03  2861.610  2883.1000  2848.0100  2874.79   992718
# ...              ...        ...        ...      ...      ...
# 2021-01-08  1777.160  1799.3550  1761.2200  1797.83  1774226
# 2021-01-07  1726.760  1777.8200  1726.7600  1774.34  2096829
# 2021-01-06  1700.255  1743.9650  1696.1014  1722.88  2329401
# 2021-01-05  1725.090  1746.8300  1716.9000  1740.05  1017962
# 2021-01-04  1760.000  1762.4899  1707.1400  1726.13  1866195
#
# [174 rows x 5 columns]

# %%
data["Close"][0]
# Out:
# 2817.52
